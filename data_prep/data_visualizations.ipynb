# %%
#  Required Install
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (0.8.0)
# Requirement already satisfied: pooch>=1.0 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from librosa) (1.3.0)
# Requirement already satisfied: audioread>=2.0.0 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from librosa) (2.1.9)
# Requirement already satisfied: joblib>=0.14 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from librosa) (1.0.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from librosa) (1.19.5)
# Requirement already satisfied: scipy>=1.0.0 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from librosa) (1.5.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from librosa) (0.23.2)
# Requirement already satisfied: decorator>=3.0.0 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from librosa) (4.4.2)
# Requirement already satisfied: soundfile>=0.9.0 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: resampy>=0.2.2 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from librosa) (0.2.2)
# Requirement already satisfied: numba>=0.43.0 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from librosa) (0.52.0)
# Requirement already satisfied: setuptools in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from numba>=0.43.0->librosa) (52.0.0.post20210125)
# Requirement already satisfied: llvmlite<0.36,>=0.35.0 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from numba>=0.43.0->librosa) (0.35.0)
# Requirement already satisfied: appdirs in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from pooch>=1.0->librosa) (2.25.1)
# Requirement already satisfied: packaging in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from pooch>=1.0->librosa) (20.9)
# Requirement already satisfied: six>=1.3 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from resampy>=0.2.2->librosa) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (2.1.0)
# Requirement already satisfied: cffi>=1.0 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from soundfile>=0.9.0->librosa) (1.14.4)
# Requirement already satisfied: pycparser in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from cffi>=1.0->soundfile>=0.9.0->librosa) (2.20)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from packaging->pooch>=1.0->librosa) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from requests->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from requests->pooch>=1.0->librosa) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from requests->pooch>=1.0->librosa) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/timsamson/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages (from requests->pooch>=1.0->librosa) (1.26.3)

# %%
#Import Dependencies
from pylab import *
import os
import pandas as pd
import librosa
import librosa.display
import glob
import random

# %% [markdown]
# # RAVDASS AUDIO SET

# %% [markdown]
# # Generate list of file and apply emotion str

# %%
##Get list of Files in folder
file_name = []

for root, dirs, files in os.walk("../data/emotion_speech/."):
    for filename in files:
        file_name.append(filename)

file_name_df = pd.DataFrame(file_name, columns = ['file_name'])
file_name_df['encoding']= file_name_df['file_name']
file_name_df['ID'] = file_name_df.index 
file_name_df['dir']= 'emotion_speech'
file_name_df
# Out:
#                      file_name                  encoding    ID             dir
# 0     03-01-06-01-02-02-02.wav  03-01-06-01-02-02-02.wav     0  emotion_speech
# 1     03-01-05-01-02-01-16.wav  03-01-05-01-02-01-16.wav     1  emotion_speech
# 2     03-01-08-01-01-01-14.wav  03-01-08-01-01-01-14.wav     2  emotion_speech
# 3     03-01-06-01-02-02-16.wav  03-01-06-01-02-02-16.wav     3  emotion_speech
# 4     03-01-05-01-02-01-02.wav  03-01-05-01-02-01-02.wav     4  emotion_speech
# ...                        ...                       ...   ...             ...
# 1435  03-01-08-02-02-01-19.wav  03-01-08-02-02-01-19.wav  1435  emotion_speech
# 1436  03-01-02-02-01-01-23.wav  03-01-02-02-01-01-23.wav  1436  emotion_speech
# 1437  03-01-02-01-02-01-23.wav  03-01-02-01-02-01-23.wav  1437  emotion_speech
# 1438  03-01-08-01-01-01-19.wav  03-01-08-01-01-01-19.wav  1438  emotion_speech
# 1439  03-01-01-01-02-02-23.wav  03-01-01-01-02-02-23.wav  1439  emotion_speech
#
# [1440 rows x 4 columns]

# %%
encoding_df = file_name_df["encoding"].str.split("-", n=-1, expand=True)
encoding_df.columns = ['Modality','Vocal_channel','Class','Intensity','Statement','Repetition','Actor']


"""
1. Added a new column - Gender
2. Populated Gender column after stripping .wav from 'Actor'
3. Convert data type from obj to string then to int which is 
   needed to determine odd or even
"""
encoding_df['Actor'] = encoding_df['Actor'].map(lambda actor: actor.rstrip('.wav'))
encoding_df['Gender'] = 'Gender'
encoding_df['Actor'].astype(str).astype(int)

encoding_df
"""
1. Loop through each row in dataframe 'Actor' column
2. Set value of Gender to Female if Actor value is even or Male if odd
"""
for index, row in encoding_df.iterrows():
    if int(row[6]) % 2 == 0:
        row['Gender'] = '1'
    else:
        row['Gender'] = '0'
        
# encoding_df

final_df = encoding_df.drop(columns=['Modality','Vocal_channel','Intensity','Statement','Repetition','Actor'])

final_df.loc[final_df.Class == '01', 'Class'] = '02'
final_df.loc[final_df.Class == '02', 'Emotion'] = 'calm'
final_df.loc[final_df.Class == '03', 'Emotion'] = 'happy'
final_df.loc[final_df.Class == '04', 'Emotion'] = 'sad'
final_df.loc[final_df.Class == '05', 'Emotion'] = 'angry'
final_df.loc[final_df.Class == '06', 'Emotion'] = 'fearful'
final_df.loc[final_df.Class == '07', 'Emotion'] = 'disgust'
final_df.loc[final_df.Class == '08', 'Emotion'] = 'surprise'


final_df
# Out:
#      Class Gender   Emotion
# 0       06      1   fearful
# 1       05      1     angry
# 2       08      1  surprise
# 3       06      1   fearful
# 4       05      1     angry
# ...    ...    ...       ...
# 1435    08      0  surprise
# 1436    02      0      calm
# 1437    02      0      calm
# 1438    08      0  surprise
# 1439    02      0      calm
#
# [1440 rows x 3 columns]

# %%
#merge data frame
pre_merged_df = file_name_df.join(final_df, how='outer')
merged_df = pre_merged_df.drop(columns=['encoding'])
merged_df.set_index('ID')
# Out:
#                      file_name             dir Class Gender   Emotion
# ID
# 0     03-01-06-01-02-02-02.wav  emotion_speech    06      1   fearful
# 1     03-01-05-01-02-01-16.wav  emotion_speech    05      1     angry
# 2     03-01-08-01-01-01-14.wav  emotion_speech    08      1  surprise
# 3     03-01-06-01-02-02-16.wav  emotion_speech    06      1   fearful
# 4     03-01-05-01-02-01-02.wav  emotion_speech    05      1     angry
# ...                        ...             ...   ...    ...       ...
# 1435  03-01-08-02-02-01-19.wav  emotion_speech    08      0  surprise
# 1436  03-01-02-02-01-01-23.wav  emotion_speech    02      0      calm
# 1437  03-01-02-01-02-01-23.wav  emotion_speech    02      0      calm
# 1438  03-01-08-01-01-01-19.wav  emotion_speech    08      0  surprise
# 1439  03-01-01-01-02-02-23.wav  emotion_speech    02      0      calm
#
# [1440 rows x 5 columns]

# %%
merged_df.Class.value_counts()
# Out:
# 02    288
# 04    192
# 08    192
# 05    192
# 03    192
# 06    192
# 07    192
# Name: Class, dtype: int64

# %% [markdown]
# # TORONTO EMOTIONAL SPEECH DATASET

# %%
##Get list of Files in folder
t_file_name = []

for root, dirs, files in os.walk("../data/toronto_speech/."):
    for filename in files:
        t_file_name.append(filename)

t_file_name_df = pd.DataFrame(t_file_name, columns = ['file_name'])
t_file_name_df['encoding']= t_file_name_df['file_name']
t_file_name_df['ID'] = t_file_name_df.index 
t_file_name_df['dir'] = 'toronto_speech'
t_file_name_df.head(20)
# Out:
#                file_name              encoding  ID             dir
# 0     YAF_wire_happy.wav    YAF_wire_happy.wav   0  toronto_speech
# 1    OAF_fat_disgust.wav   OAF_fat_disgust.wav   1  toronto_speech
# 2   OAF_bought_happy.wav  OAF_bought_happy.wav   2  toronto_speech
# 3    OAF_fit_neutral.wav   OAF_fit_neutral.wav   3  toronto_speech
# 4      YAF_dead_fear.wav     YAF_dead_fear.wav   4  toronto_speech
# 5   OAF_join_neutral.wav  OAF_join_neutral.wav   5  toronto_speech
# 6     YAF_hall_happy.wav    YAF_hall_happy.wav   6  toronto_speech
# 7   YAF_hurl_neutral.wav  YAF_hurl_neutral.wav   7  toronto_speech
# 8     OAF_king_angry.wav    OAF_king_angry.wav   8  toronto_speech
# 9      OAF_rot_angry.wav     OAF_rot_angry.wav   9  toronto_speech
# 10        YAF_hit_ps.wav        YAF_hit_ps.wav  10  toronto_speech
# 11      OAF_gaze_sad.wav      OAF_gaze_sad.wav  11  toronto_speech
# 12     YAF_ripe_fear.wav     YAF_ripe_fear.wav  12  toronto_speech
# 13   YAF_dog_neutral.wav   YAF_dog_neutral.wav  13  toronto_speech
# 14    OAF_hire_angry.wav    OAF_hire_angry.wav  14  toronto_speech
# 15      OAF_neat_sad.wav      OAF_neat_sad.wav  15  toronto_speech
# 16     YAF_gin_happy.wav     YAF_gin_happy.wav  16  toronto_speech
# 17   YAF_sub_neutral.wav   YAF_sub_neutral.wav  17  toronto_speech
# 18     OAF_mouse_sad.wav     OAF_mouse_sad.wav  18  toronto_speech
# 19  OAF_ripe_disgust.wav  OAF_ripe_disgust.wav  19  toronto_speech

# %%
t_encoding_df = t_file_name_df["encoding"].str.split("_", n=-1, expand=True)
t_encoding_df.columns = ['Actor','Word','Emotion']
t_encoding_df['Gender'] = '1'
t_final_df = t_encoding_df.drop(columns=['Actor','Word'])
t_final_df['Emotion'] = t_final_df['Emotion'].str.strip('.wav')
toronto_df = pd.DataFrame(t_final_df)
toronto_df
# Out:
#       Emotion Gender
# 0       happy      1
# 1     disgust      1
# 2       happy      1
# 3     neutral      1
# 4        fear      1
# ...       ...    ...
# 2795      sad      1
# 2796     fear      1
# 2797  neutral      1
# 2798    happy      1
# 2799  disgust      1
#
# [2800 rows x 2 columns]

# %%
#Fix odd values in file and convert Nuetral class to calm
toronto_df.loc[toronto_df.Emotion == 'ps', 'Emotion'] = 'surprise'
toronto_df.loc[toronto_df.Emotion == 'alm', 'Emotion'] = 'calm'
toronto_df.loc[toronto_df.Emotion == 'ngry', 'Emotion'] = 'angry'
toronto_df.loc[toronto_df.Emotion == 'neutral', 'Emotion'] = 'calm'
toronto_df.loc[toronto_df.Emotion == 'fear', 'Emotion'] = 'fearful'

#assign emotion value numbers
toronto_df.loc[toronto_df.Emotion == 'calm', 'Class'] = '02'
toronto_df.loc[toronto_df.Emotion == 'happy', 'Class'] = '03'
toronto_df.loc[toronto_df.Emotion == 'sad', 'Class'] = '04'
toronto_df.loc[toronto_df.Emotion == 'angry', 'Class'] = '05'
toronto_df.loc[toronto_df.Emotion == 'fearful', 'Class'] = '06'
toronto_df.loc[toronto_df.Emotion == 'disgust', 'Class'] = '07'
toronto_df.loc[toronto_df.Emotion == 'surprise', 'Class'] = '08'

toronto_df.head(15)
# Out:
#      Emotion Gender Class
# 0      happy      1    03
# 1    disgust      1    07
# 2      happy      1    03
# 3       calm      1    02
# 4    fearful      1    06
# 5       calm      1    02
# 6      happy      1    03
# 7       calm      1    02
# 8      angry      1    05
# 9      angry      1    05
# 10  surprise      1    08
# 11       sad      1    04
# 12   fearful      1    06
# 13      calm      1    02
# 14     angry      1    05

# %%
#merge data frame and export CSV
t_pre_merged_df = t_file_name_df.join(toronto_df, how='outer')
t_merged_df = t_pre_merged_df.drop(columns=['encoding'])
t_merged_df = t_merged_df[['file_name', 'dir', 'Class','Gender','Emotion','ID']]
t_merged_df
t_merged_df.set_index('ID')
# Out:
#                  file_name             dir Class Gender  Emotion
# ID
# 0       YAF_wire_happy.wav  toronto_speech    03      1    happy
# 1      OAF_fat_disgust.wav  toronto_speech    07      1  disgust
# 2     OAF_bought_happy.wav  toronto_speech    03      1    happy
# 3      OAF_fit_neutral.wav  toronto_speech    02      1     calm
# 4        YAF_dead_fear.wav  toronto_speech    06      1  fearful
# ...                    ...             ...   ...    ...      ...
# 2795      OAF_rain_sad.wav  toronto_speech    04      1      sad
# 2796     OAF_kill_fear.wav  toronto_speech    06      1  fearful
# 2797  OAF_vine_neutral.wav  toronto_speech    02      1     calm
# 2798    OAF_hate_happy.wav  toronto_speech    03      1    happy
# 2799   OAF_cab_disgust.wav  toronto_speech    07      1  disgust
#
# [2800 rows x 5 columns]

# %%
t_merged_df.Class.value_counts()
# Out:
# 04    400
# 08    400
# 03    400
# 06    400
# 02    400
# 05    400
# 07    400
# Name: Class, dtype: int64

# %% [markdown]
# # CONCAT DATASETS & RESET INDEX

# %%
dataset_df = pd.concat([merged_df, t_merged_df])
dataset2 = dataset_df.reset_index(drop=True)
dataset2['ID']= dataset2.index
final_dataset_df = dataset2
final_dataset_df
# Out:
#                      file_name    ID             dir Class Gender   Emotion
# 0     03-01-06-01-02-02-02.wav     0  emotion_speech    06      1   fearful
# 1     03-01-05-01-02-01-16.wav     1  emotion_speech    05      1     angry
# 2     03-01-08-01-01-01-14.wav     2  emotion_speech    08      1  surprise
# 3     03-01-06-01-02-02-16.wav     3  emotion_speech    06      1   fearful
# 4     03-01-05-01-02-01-02.wav     4  emotion_speech    05      1     angry
# ...                        ...   ...             ...   ...    ...       ...
# 4235          OAF_rain_sad.wav  4235  toronto_speech    04      1       sad
# 4236         OAF_kill_fear.wav  4236  toronto_speech    06      1   fearful
# 4237      OAF_vine_neutral.wav  4237  toronto_speech    02      1      calm
# 4238        OAF_hate_happy.wav  4238  toronto_speech    03      1     happy
# 4239       OAF_cab_disgust.wav  4239  toronto_speech    07      1   disgust
#
# [4240 rows x 6 columns]

# %%
final_dataset_df.Emotion.value_counts()
# Out:
# calm        688
# sad         592
# disgust     592
# happy       592
# surprise    592
# angry       592
# fearful     592
# Name: Emotion, dtype: int64

# %%
final_dataset_df.Class.value_counts()
# Out:
# 02    688
# 06    592
# 05    592
# 04    592
# 07    592
# 08    592
# 03    592
# Name: Class, dtype: int64

# %%
final_dataset_df.to_csv(r'../data/voice_feature_data.csv', index = True)

# %%
train = pd.read_csv('../data/voice_feature_data.csv')
data_dir = ('../data')
train.head()
# Out:
#    Unnamed: 0                 file_name  ID             dir  Class   Emotion
# 0           0  03-01-06-01-02-02-02.wav   0  emotion_speech      6   fearful
# 1           1  03-01-05-01-02-01-16.wav   1  emotion_speech      5     angry
# 2           2  03-01-08-01-01-01-14.wav   2  emotion_speech      8  surprise
# 3           3  03-01-06-01-02-02-16.wav   3  emotion_speech      6   fearful
# 4           4  03-01-05-01-02-01-02.wav   4  emotion_speech      5     angry

# %% [markdown]
# # CREATE FEATURES

# %%
train.Class.value_counts()
# Out:
# 2    688
# 7    592
# 3    592
# 6    592
# 5    592
# 8    592
# 4    592
# Name: Class, dtype: int64

# %%
def parser(row):
   # function to load files and extract features
   file_name = os.path.join(os.path.abspath(data_dir), str(row.dir), str(row.file_name))

   # handle exception to check if there isn't a file which is corrupted
   try:
      # extraction
      X, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
      # extract mfcc data
      mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0) 
   except Exception as e:
      print("Error encountered while parsing file: ", file_name)
      return None, None
 
   feature = mfccs
   label = row.Class
   emotion = row.Emotion

 
   return [feature, label, emotion]

temp = train.apply(parser, axis=1)

# %%
temp.to_csv(r'../data/temp_review.csv', index = True)
temp
# Out:
# 0       [[-573.37915, 34.06404, -33.337578, 3.4899156,...
# 1       [[-545.24457, 38.073475, -8.023163, 7.236882, ...
# 2       [[-690.53546, 43.141396, -9.854416, 10.81954, ...
# 3       [[-553.61163, 41.233486, -9.912664, 8.587062, ...
# 4       [[-576.15344, 49.947994, -13.857949, 8.248825,...
#                               ...
# 4235    [[-540.3414, 88.73076, 24.931204, 16.717299, 1...
# 4236    [[-422.4946, 53.755165, -2.5026753, 7.4916716,...
# 4237    [[-503.59506, 93.18696, 12.731936, 10.6216, 0....
# 4238    [[-463.14896, 82.21518, 6.5161567, 3.6688368, ...
# 4239    [[-462.23047, 87.86248, 6.312949, 0.8862172, 6...
# Length: 4240, dtype: object

# %%
features = [x[0] for x in temp]
features

labels = [x[1] for x in temp]
labels

emotions = [x[2] for x in temp]
emotions
# Out:
# ['fearful',
#  'angry',
#  'surprise',
#  'fearful',
#  'angry',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'fearful',
#  'angry',
#  'surprise',
#  'fearful',
#  'angry',
#  'angry',
#  'surprise',
#  'fearful',
#  'surprise',
#  'surprise',
#  'fearful',
#  'surprise',
#  'angry',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'sad',
#  'disgust',
#  'disgust',
#  'sad',
#  'sad',
#  'disgust',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'angry',
#  'fearful',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'surprise',
#  'angry',
#  'fearful',
#  'angry',
#  'fearful',
#  'surprise',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'surprise',
#  'angry',
#  'fearful',
#  'angry',
#  'fearful',
#  'surprise',
#  'fearful',
#  'angry',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'fearful',
#  'angry',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'calm',
#  'fearful',
#  'surprise',
#  'angry',
#  'calm',
#  'angry',
#  'fearful',
#  'fearful',
#  'angry',
#  'calm',
#  'angry',
#  'surprise',
#  'fearful',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'sad',
#  'happy',
#  'disgust',
#  'disgust',
#  'happy',
#  'sad',
#  'sad',
#  'disgust',
#  'happy',
#  'disgust',
#  'sad',
#  'sad',
#  'happy',
#  'disgust',
#  'disgust',
#  'happy',
#  'sad',
#  'sad',
#  'disgust',
#  'happy',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'surprise',
#  'fearful',
#  'angry',
#  'calm',
#  'angry',
#  'calm',
#  'fearful',
#  'fearful',
#  'calm',
#  'calm',
#  'angry',
#  'calm',
#  'angry',
#  'fearful',
#  'calm',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'surprise',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'surprise',
#  'angry',
#  'fearful',
#  'surprise',
#  'calm',
#  'calm',
#  'surprise',
#  'angry',
#  'fearful',
#  'angry',
#  'fearful',
#  'surprise',
#  'surprise',
#  'angry',
#  'fearful',
#  'angry',
#  'fearful',
#  'surprise',
#  'calm',
#  'fearful',
#  'calm',
#  'calm',
#  'angry',
#  'calm',
#  'fearful',
#  'angry',
#  'calm',
#  'angry',
#  'fearful',
#  'calm',
#  'angry',
#  'calm',
#  'fearful',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'sad',
#  'happy',
#  'disgust',
#  'happy',
#  'sad',
#  'disgust',
#  'disgust',
#  'sad',
#  'happy',
#  'disgust',
#  'happy',
#  'sad',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'fearful',
#  'calm',
#  'angry',
#  'calm',
#  'calm',
#  'calm',
#  'angry',
#  'calm',
#  'calm',
#  'fearful',
#  'calm',
#  'calm',
#  'fearful',
#  'angry',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'fearful',
#  'angry',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'surprise',
#  'angry',
#  'fearful',
#  'angry',
#  'fearful',
#  'surprise',
#  'surprise',
#  'angry',
#  'fearful',
#  'angry',
#  'fearful',
#  'surprise',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'surprise',
#  'surprise',
#  'calm',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'calm',
#  'surprise',
#  'surprise',
#  'surprise',
#  'calm',
#  'surprise',
#  'calm',
#  'calm',
#  'calm',
#  'fearful',
#  'angry',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'fearful',
#  'angry',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'surprise',
#  'fearful',
#  'angry',
#  'fearful',
#  'angry',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'fearful',
#  'angry',
#  'surprise',
#  'calm',
#  'angry',
#  'calm',
#  'calm',
#  'fearful',
#  'calm',
#  'angry',
#  'fearful',
#  'calm',
#  'calm',
#  'fearful',
#  'angry',
#  'fearful',
#  'calm',
#  'angry',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'disgust',
#  'happy',
#  'sad',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'sad',
#  'happy',
#  'disgust',
#  'happy',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'happy',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'angry',
#  'calm',
#  'fearful',
#  'calm',
#  'calm',
#  'calm',
#  'fearful',
#  'calm',
#  'calm',
#  'angry',
#  'calm',
#  'calm',
#  'angry',
#  'fearful',
#  'surprise',
#  'surprise',
#  'angry',
#  'fearful',
#  'angry',
#  'fearful',
#  'surprise',
#  'surprise',
#  'angry',
#  'fearful',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'surprise',
#  'fearful',
#  'angry',
#  'fearful',
#  'angry',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'fearful',
#  'angry',
#  'surprise',
#  'calm',
#  'calm',
#  'surprise',
#  'calm',
#  'calm',
#  'calm',
#  'surprise',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'surprise',
#  'calm',
#  'surprise',
#  'surprise',
#  'calm',
#  'surprise',
#  'calm',
#  'calm',
#  'calm',
#  'angry',
#  'fearful',
#  'surprise',
#  'surprise',
#  'angry',
#  'fearful',
#  'angry',
#  'fearful',
#  'surprise',
#  'surprise',
#  'angry',
#  'fearful',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'angry',
#  'fearful',
#  'surprise',
#  'angry',
#  'fearful',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'angry',
#  'fearful',
#  'surprise',
#  'angry',
#  'fearful',
#  'fearful',
#  'surprise',
#  'angry',
#  'surprise',
#  'surprise',
#  'angry',
#  'surprise',
#  'fearful',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'disgust',
#  'sad',
#  'sad',
#  'disgust',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'happy',
#  'happy',
#  'surprise',
#  'fearful',
#  'angry',
#  'surprise',
#  'surprise',
#  'angry',
#  'fearful',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'fearful',
#  'angry',
#  'surprise',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'surprise',
#  'fearful',
#  'angry',
#  'fearful',
#  'angry',
#  'surprise',
#  'angry',
#  'fearful',
#  'surprise',
#  'surprise',
#  'angry',
#  'fearful',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'angry',
#  'fearful',
#  'surprise',
#  'surprise',
#  'angry',
#  'fearful',
#  'calm',
#  'angry',
#  'surprise',
#  'fearful',
#  'calm',
#  'fearful',
#  'angry',
#  'angry',
#  'fearful',
#  'fearful',
#  'surprise',
#  'angry',
#  'calm',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'disgust',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'disgust',
#  'disgust',
#  'sad',
#  'sad',
#  'disgust',
#  'happy',
#  'disgust',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'disgust',
#  'happy',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'sad',
#  'disgust',
#  'happy',
#  'happy',
#  'calm',
#  'angry',
#  'fearful',
#  'surprise',
#  'fearful',
#  'calm',
#  'angry',
#  'angry',
#  'calm',
#  'calm',
#  'fearful',
#  'surprise',
#  'calm',
#  'fearful',
#  'angry',
#  'calm',
#  'surprise',
#  'angry',
#  'fearful',
#  'surprise',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'surprise',
#  'fearful',
#  'angry',
#  'surprise',
#  'calm',
#  'fearful',
#  'angry',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'angry',
#  'fearful',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'surprise',
#  'angry',
#  'fearful',
#  'angry',
#  'fearful',
#  'surprise',
#  'surprise',
#  'angry',
#  'fearful',
#  'angry',
#  'fearful',
#  'surprise',
#  'calm',
#  'calm',
#  'happy',
#  'sad',
#  'happy',
#  'disgust',
#  'disgust',
#  'happy',
#  'sad',
#  'happy',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'happy',
#  'sad',
#  'happy',
#  'disgust',
#  'disgust',
#  'happy',
#  'sad',
#  'happy',
#  'disgust',
#  'sad',
#  'calm',
#  'fearful',
#  'angry',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'fearful',
#  'angry',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'calm',
#  'calm',
#  'fearful',
#  'angry',
#  'calm',
#  'fearful',
#  'calm',
#  'angry',
#  'angry',
#  'calm',
#  'calm',
#  'fearful',
#  'calm',
#  'angry',
#  'fearful',
#  'calm',
#  'calm',
#  'calm',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'surprise',
#  'angry',
#  'fearful',
#  'angry',
#  'fearful',
#  'surprise',
#  'surprise',
#  'angry',
#  'fearful',
#  'angry',
#  'fearful',
#  'surprise',
#  'calm',
#  'calm',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'happy',
#  'happy',
#  'calm',
#  'calm',
#  'fearful',
#  'angry',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'fearful',
#  'angry',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'surprise',
#  'calm',
#  'surprise',
#  'calm',
#  'angry',
#  'surprise',
#  'fearful',
#  'surprise',
#  'surprise',
#  'fearful',
#  'surprise',
#  'angry',
#  'fearful',
#  'angry',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'fearful',
#  'angry',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'disgust',
#  'sad',
#  'sad',
#  'disgust',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'sad',
#  'disgust',
#  'angry',
#  'fearful',
#  'angry',
#  'fearful',
#  'surprise',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'surprise',
#  'angry',
#  'fearful',
#  'angry',
#  'fearful',
#  'angry',
#  'fearful',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'fearful',
#  'angry',
#  'fearful',
#  'calm',
#  'surprise',
#  'calm',
#  'angry',
#  'calm',
#  'angry',
#  'fearful',
#  'calm',
#  'calm',
#  'fearful',
#  'angry',
#  'angry',
#  'calm',
#  'surprise',
#  'fearful',
#  'fearful',
#  'surprise',
#  'surprise',
#  'angry',
#  'calm',
#  'calm',
#  'calm',
#  ...]

# %%
features_df = pd.DataFrame(data=features)
features_df
# Out:
#               0          1          2          3          4          5   \
# 0    -573.379150  34.064041 -33.337578   3.489916 -13.482152  -6.327230
# 1    -545.244568  38.073475  -8.023163   7.236882 -13.688817  -2.157916
# 2    -690.535461  43.141396  -9.854416  10.819540 -14.295117  -2.288000
# 3    -553.611633  41.233486  -9.912664   8.587062  -5.737630  -5.831647
# 4    -576.153442  49.947994 -13.857949   8.248825 -12.159565   0.193613
# ...          ...        ...        ...        ...        ...        ...
# 4235 -540.341370  88.730759  24.931204  16.717299  12.627458  23.086229
# 4236 -422.494598  53.755165  -2.502675   7.491672 -12.121218   5.712925
# 4237 -503.595062  93.186958  12.731936  10.621600   0.938329  16.996798
# 4238 -463.148956  82.215179   6.516157   3.668837  -5.777552   4.530595
# 4239 -462.230469  87.862480   6.312949   0.886217   6.711632  10.299251
#
#              6          7          8         9   ...        30         31  \
# 0    -17.734171 -15.280939  -8.379515 -0.323866  ... -4.505692  -0.138160
# 1    -12.315373  -7.948586 -14.858138  1.719064  ...  3.918904   3.469327
# 2    -10.151420  -4.941710  -6.615477 -2.972474  ... -1.102092   0.658183
# 3    -17.839375 -11.084945 -11.369494  3.470583  ...  0.062081   0.015738
# 4     -8.719680  -7.731156  -8.692744  0.833810  ...  0.995639   2.204446
# ...         ...        ...        ...       ...  ...       ...        ...
# 4235 -16.912727  -9.665927 -21.919531  7.123326  ...  2.553871  11.440205
# 4236 -20.065599   4.435990 -20.681208 -0.890789  ...  7.452299  -1.662737
# 4237  -7.933547  -2.902612 -17.147320 -0.593358  ... -7.690097  -6.973018
# 4238 -24.920565   6.980038 -18.783543  1.689377  ...  6.662729   7.912870
# 4239 -16.992674   7.260334 -13.879857  5.092445  ...  1.839402   3.599077
#
#             32        33         34         35         36         37  \
# 0    -1.091130 -2.829661  -1.520689  -2.216941  -3.051777   1.104535
# 1    -0.281293  0.684120   0.073632   2.641415   0.838373   1.800676
# 2    -1.439343  0.234170   0.237684   0.759627   0.519322   0.865444
# 3    -0.685990  0.215328  -0.507966   0.684138   0.205525   0.921709
# 4     0.724145  1.723078   1.540662   1.585126   0.513308   0.538170
# ...        ...       ...        ...        ...        ...        ...
# 4235  8.128857  1.503310   4.661386   2.094795   2.679550  11.995535
# 4236 -1.390796 -7.681273   2.991107   5.960479   0.115514  -5.313824
# 4237 -4.091505  4.595872  25.452799  34.336697  42.704762  32.752857
# 4238  5.802299  1.655658   3.806829   4.683732   4.972075   6.151783
# 4239  2.950867  1.947793   4.224071   5.240630   6.927167   8.176072
#
#              38         39
# 0      0.969608   2.822009
# 1     -0.601248   1.839665
# 2      1.468920   1.691772
# 3      0.126503   0.312205
# 4     -0.266717  -1.757481
# ...         ...        ...
# 4235  21.113256  20.589991
# 4236  -5.243746   1.381710
# 4237  15.370884   3.143144
# 4238   7.643718   8.755606
# 4239  11.625792  11.584822
#
# [4240 rows x 40 columns]

# %%
features_df["label"] = labels
features_df["emotions"] = emotions

features_df
# Out:
#                0          1          2          3          4          5  \
# 0    -573.379150  34.064041 -33.337578   3.489916 -13.482152  -6.327230
# 1    -545.244568  38.073475  -8.023163   7.236882 -13.688817  -2.157916
# 2    -690.535461  43.141396  -9.854416  10.819540 -14.295117  -2.288000
# 3    -553.611633  41.233486  -9.912664   8.587062  -5.737630  -5.831647
# 4    -576.153442  49.947994 -13.857949   8.248825 -12.159565   0.193613
# ...          ...        ...        ...        ...        ...        ...
# 4235 -540.341370  88.730759  24.931204  16.717299  12.627458  23.086229
# 4236 -422.494598  53.755165  -2.502675   7.491672 -12.121218   5.712925
# 4237 -503.595062  93.186958  12.731936  10.621600   0.938329  16.996798
# 4238 -463.148956  82.215179   6.516157   3.668837  -5.777552   4.530595
# 4239 -462.230469  87.862480   6.312949   0.886217   6.711632  10.299251
#
#               6          7          8         9  ...        32        33  \
# 0    -17.734171 -15.280939  -8.379515 -0.323866  ... -1.091130 -2.829661
# 1    -12.315373  -7.948586 -14.858138  1.719064  ... -0.281293  0.684120
# 2    -10.151420  -4.941710  -6.615477 -2.972474  ... -1.439343  0.234170
# 3    -17.839375 -11.084945 -11.369494  3.470583  ... -0.685990  0.215328
# 4     -8.719680  -7.731156  -8.692744  0.833810  ...  0.724145  1.723078
# ...         ...        ...        ...       ...  ...       ...       ...
# 4235 -16.912727  -9.665927 -21.919531  7.123326  ...  8.128857  1.503310
# 4236 -20.065599   4.435990 -20.681208 -0.890789  ... -1.390796 -7.681273
# 4237  -7.933547  -2.902612 -17.147320 -0.593358  ... -4.091505  4.595872
# 4238 -24.920565   6.980038 -18.783543  1.689377  ...  5.802299  1.655658
# 4239 -16.992674   7.260334 -13.879857  5.092445  ...  2.950867  1.947793
#
#              34         35         36         37         38         39  label  \
# 0     -1.520689  -2.216941  -3.051777   1.104535   0.969608   2.822009      6
# 1      0.073632   2.641415   0.838373   1.800676  -0.601248   1.839665      5
# 2      0.237684   0.759627   0.519322   0.865444   1.468920   1.691772      8
# 3     -0.507966   0.684138   0.205525   0.921709   0.126503   0.312205      6
# 4      1.540662   1.585126   0.513308   0.538170  -0.266717  -1.757481      5
# ...         ...        ...        ...        ...        ...        ...    ...
# 4235   4.661386   2.094795   2.679550  11.995535  21.113256  20.589991      4
# 4236   2.991107   5.960479   0.115514  -5.313824  -5.243746   1.381710      6
# 4237  25.452799  34.336697  42.704762  32.752857  15.370884   3.143144      2
# 4238   3.806829   4.683732   4.972075   6.151783   7.643718   8.755606      3
# 4239   4.224071   5.240630   6.927167   8.176072  11.625792  11.584822      7
#
#       emotions
# 0      fearful
# 1        angry
# 2     surprise
# 3      fearful
# 4        angry
# ...        ...
# 4235       sad
# 4236   fearful
# 4237      calm
# 4238     happy
# 4239   disgust
#
# [4240 rows x 42 columns]

# %%
#Write to CSV
features_df.to_csv('../data/voice_data.csv', index=False)
