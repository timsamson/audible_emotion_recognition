# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
filepath = "data/visualization_data.csv"

df = pd.read_csv(filepath)
df.head()
# Out:
#    Unnamed: 0           0          1          2          3          4  \
# 0           0 -573.379150  34.064041 -33.337578   3.489916 -13.482152
# 1           1 -545.244568  38.073475  -8.023163   7.236882 -13.688817
# 2           2 -690.535461  43.141396  -9.854416  10.819540 -14.295117
# 3           3 -553.611633  41.233486  -9.912664   8.587062  -5.737630
# 4           4 -576.153442  49.947994 -13.857949   8.248825 -12.159565
#
#           5          6          7          8  ...       121       122  \
# 0 -6.327230 -17.734171 -15.280939  -8.379515  ... -0.797864 -0.332338
# 1 -2.157916 -12.315373  -7.948586 -14.858138  ...  0.029629 -0.052548
# 2 -2.288000 -10.151420  -4.941710  -6.615477  ... -0.174446 -0.116118
# 3 -5.831647 -17.839375 -11.084945 -11.369494  ...  0.068388  0.201094
# 4  0.193613  -8.719680  -7.731156  -8.692744  ... -0.723615  0.074101
#
#         123       124       125       126       127  label  gender  emotions
# ...

# %%
                      
gender_group = df.groupby(["gender"])

gender_df = gender_group.mean()
gender_df
# Out:
#          Unnamed: 0           0          1         2          3         4  \
# gender
# 0        719.597222 -595.544168  61.218919 -4.612208  16.395488  1.560431
# 1       2405.843750 -447.866575  62.273846 -3.816194  14.517817 -9.581575
#
#                5          6         7          8  ...       119       120  \
# gender                                            ...
# 0       3.589963  -7.597994 -1.566539  -9.845676  ...  0.056096  0.078376
# 1       5.065226 -13.893323 -3.978203 -14.310186  ... -0.193540 -0.272221
#
#              121       122       123       124       125       126       127  \
# gender
# 0       0.151972  0.181769  0.135494  0.146898  0.098412  0.003798  0.007587
# 1      -0.182315 -0.123147 -0.060429 -0.084656 -0.087726 -0.146980 -0.045684
#
#            label
# gender
# 0       4.800000
# 1       4.959091
#
# [2 rows x 130 columns]

# %%
gender_df.drop(inplace=True, columns=(["label", "Unnamed: 0"]))
gender_dict= gender_df.to_dict('index')
gender_dict
# Out:
# {0: {'0': -595.5441677517362,
#   '1': 61.218919128841826,
#   '2': -4.6122078156642,
#   '3': 16.39548798004786,
#   '4': 1.560431036564114,
#   '5': 3.5899633850643617,
#   '6': -7.59799357823924,
#   '7': -1.5665389626889212,
#   '8': -9.84567634448823,
#   '9': 1.5663949443467169,
#   '10': -3.2505569915157846,
#   '11': -0.20456673556456936,
#   '12': -2.9135731204775057,
#   '13': 0.9415093779128964,
#   '14': -3.5500452359620898,
#   '15': 2.106378213737884,
#   '16': -4.664550865436387,
#   '17': 0.09282867795813622,
#   '18': -1.7200255223912084,
#   '19': 0.18285511890490952,
#   '20': -3.5845436044891055,
#   '21': 0.28114199429360776,
#   '22': -2.22840700761428,
#   '23': -0.5472700281514942,
#   '24': -1.3516730928473408,
#   '25': 1.209916724961709,
#   '26': -1.2075628252641764,
#   '27': 1.2823854402778427,
#   '28': -0.08046615990420428,
#   '29': 0.6109875686547538,
#   '30': 0.32303212764672934,
#   '31': 0.4542820213543665,
#   '32': 0.23606666790292366,
# ...

# %%
new_df = pd.DataFrame.from_dict(gender_dict)
new_df
# Out:
#               0           1
# 0   -595.544168 -447.866575
# 1     61.218919   62.273846
# 2     -4.612208   -3.816194
# 3     16.395488   14.517817
# 4      1.560431   -9.581575
# ..          ...         ...
# 123    0.135494   -0.060429
# 124    0.146898   -0.084656
# 125    0.098412   -0.087726
# 126    0.003798   -0.146980
# 127    0.007587   -0.045684
#
# [128 rows x 2 columns]

# %%
new_df.columns = ['Masculine', 'Feminine']
new_df
# Out:
#      Masculine   Feminine
# 1    61.218919  62.273846
# 2    -4.612208  -3.816194
# 3    16.395488  14.517817
# 4     1.560431  -9.581575
# 5     3.589963   5.065226
# ..         ...        ...
# 123   0.135494  -0.060429
# 124   0.146898  -0.084656
# 125   0.098412  -0.087726
# 126   0.003798  -0.146980
# 127   0.007587  -0.045684
#
# [127 rows x 2 columns]

# %%
new_df.drop('0', axis=0, inplace=True)
new_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-a2bd518a9217> in <module>
# ----> 1 new_df.drop('0', axis=0, inplace=True)
#       2 new_df
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4168             level=level,
#    4169             inplace=inplace,
# -> 4170             errors=errors,
#    4171         )
#    4172
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
new_df.to_csv("data/gender_column.csv", encoding='utf-8', index=True)

# %%
male = new_df.plot.line(y='Masculine', figsize=(10, 4), color='black', title="Masculine")
male.set_xlabel("Feature")
male.set_ylabel("Frequency")

fig = male.get_figure()
fig.savefig("static/img/male_line.png")

# %%
female = new_df.plot.line(y='Feminine', figsize=(10, 4), color='magenta', title="Feminine")
female.set_xlabel("Feature")
female.set_ylabel("Frequency")
fig = female.get_figure()
fig.savefig("static/img/female_line.png")
