# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import pandas as pd
import os
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('../data/gen_emo_data.csv')
df
# Out:
#                0          1          2          3          4         5  \
# 0    -700.398926  58.630211  -3.025852  16.040241   4.248529  3.869935
# 1    -653.169006  58.028076 -12.581207  11.818786  -7.681562 -0.617142
# 2    -617.052307  60.103371  -5.984258  13.886285   1.120427  0.511750
# 3    -698.721130  47.088486 -11.333612  12.963088  -8.005651 -1.252229
# 4    -715.922607  71.976799   4.457525  18.602499   8.404046  3.621954
# ...          ...        ...        ...        ...        ...       ...
# 1435 -601.486267  38.448559 -22.685497   8.910748 -11.831654 -2.034770
# 1436 -517.663330  48.196037  -7.373577  14.659329  -1.055892 -2.390893
# 1437 -540.463501  30.472212 -19.334326  -0.281677  -8.792910 -2.494792
# 1438 -528.762939  37.675549 -15.573382   2.211398  -5.781027 -1.257423
# 1439 -521.966797  35.219460  -9.518683   4.339986 -10.583793 -2.021895
#
#               6          7          8         9  ...       120       121  \
# 0     -6.381716  -0.188635 -13.735003 -0.319724  ...  0.043364 -0.118930
# 1     -8.337758  -5.823570  -6.547592  1.458057  ... -0.441313 -0.270397
# 2    -14.841358  -4.016369  -5.575839 -6.309851  ...  0.018517  0.039327
# 3    -10.009068  -9.434125 -10.318875 -0.864674  ... -0.238024 -0.276562
# 4     -1.974365   0.022673  -2.678083  4.232803  ... -0.215464  0.402756
# ...         ...        ...        ...       ...  ...       ...       ...
# 1435 -15.193531 -13.168941  -8.239002 -0.204330  ...  0.068452 -0.364816
# 1436 -10.052640  -4.078947 -18.799498  3.597913  ... -0.008922  0.079820
# 1437 -18.783411  -5.102601 -17.537779  3.291184  ... -0.113637  0.126911
# 1438 -13.559296  -4.513864 -13.425216 -1.664613  ...  0.028362 -0.030429
# 1439 -16.127348  -2.097119 -12.427966  1.951031  ... -0.176526  0.129111
#
#            122       123       124       125       126       127  label  \
# 0     0.086475  0.020726 -0.009119  0.028229  0.139806 -0.038748      0
# 1    -0.072456 -0.126832  0.204340  0.047925 -0.173506  0.012698      1
# 2     0.347483  0.340563  0.208704 -0.167646  0.078711 -0.066652      0
# 3    -0.140813  0.068313 -0.155587 -0.085290 -0.532761 -0.309992      1
# 4     0.292296 -0.007742  0.232237 -0.152113 -0.026279  0.499299      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 1435  0.028009  0.067315 -0.017546  0.312544 -0.114228 -0.213653      1
# 1436  0.187155 -0.014433 -0.040827  0.515448  0.224131 -0.227128      0
# 1437  0.053742 -0.225688 -0.213271 -0.129235 -0.121047 -0.032382      1
# 1438  0.146753 -0.286557 -0.140227 -0.119282 -0.054225  0.139255      0
# 1439 -0.232738 -0.479253  0.082821  0.118256  0.154021  0.324169      1
#
#       emotions
# 0         calm
# 1         calm
# 2         calm
# 3         calm
# 4         calm
# ...        ...
# 1435  surprise
# 1436  surprise
# 1437  surprise
# 1438  surprise
# 1439  surprise
#
# [1440 rows x 130 columns]

# %%
df.drop(inplace=True, columns=["emotions"])
df.head()
# Out:
#             0          1          2          3         4         5          6  \
# 0 -700.398926  58.630211  -3.025852  16.040241  4.248529  3.869935  -6.381716
# 1 -653.169006  58.028076 -12.581207  11.818786 -7.681562 -0.617142  -8.337758
# 2 -617.052307  60.103371  -5.984258  13.886285  1.120427  0.511750 -14.841358
# 3 -698.721130  47.088486 -11.333612  12.963088 -8.005651 -1.252229 -10.009068
# 4 -715.922607  71.976799   4.457525  18.602499  8.404046  3.621954  -1.974365
#
#           7          8         9  ...       119       120       121       122  \
# 0 -0.188635 -13.735003 -0.319724  ... -0.009966  0.043364 -0.118930  0.086475
# 1 -5.823570  -6.547592  1.458057  ...  0.047958 -0.441313 -0.270397 -0.072456
# 2 -4.016369  -5.575839 -6.309851  ...  0.189555  0.018517  0.039327  0.347483
# 3 -9.434125 -10.318875 -0.864674  ...  0.171895 -0.238024 -0.276562 -0.140813
# 4  0.022673  -2.678083  4.232803  ... -0.165444 -0.215464  0.402756  0.292296
#
#         123       124       125       126       127  label
# 0  0.020726 -0.009119  0.028229  0.139806 -0.038748      0
# 1 -0.126832  0.204340  0.047925 -0.173506  0.012698      1
# 2  0.340563  0.208704 -0.167646  0.078711 -0.066652      0
# 3  0.068313 -0.155587 -0.085290 -0.532761 -0.309992      1
# 4 -0.007742  0.232237 -0.152113 -0.026279  0.499299      0
#
# [5 rows x 129 columns]

# %%
target = df["label"]

# %%
data = df.drop("label", axis=1)
feature_names = data.columns
data.head()
# Out:
#             0          1          2          3         4         5          6  \
# 0 -700.398926  58.630211  -3.025852  16.040241  4.248529  3.869935  -6.381716
# 1 -653.169006  58.028076 -12.581207  11.818786 -7.681562 -0.617142  -8.337758
# 2 -617.052307  60.103371  -5.984258  13.886285  1.120427  0.511750 -14.841358
# 3 -698.721130  47.088486 -11.333612  12.963088 -8.005651 -1.252229 -10.009068
# 4 -715.922607  71.976799   4.457525  18.602499  8.404046  3.621954  -1.974365
#
#           7          8         9  ...       118       119       120       121  \
# 0 -0.188635 -13.735003 -0.319724  ... -0.048826 -0.009966  0.043364 -0.118930
# 1 -5.823570  -6.547592  1.458057  ... -0.151122  0.047958 -0.441313 -0.270397
# 2 -4.016369  -5.575839 -6.309851  ...  0.002693  0.189555  0.018517  0.039327
# 3 -9.434125 -10.318875 -0.864674  ... -0.421341  0.171895 -0.238024 -0.276562
# 4  0.022673  -2.678083  4.232803  ...  0.384698 -0.165444 -0.215464  0.402756
#
#         122       123       124       125       126       127
# 0  0.086475  0.020726 -0.009119  0.028229  0.139806 -0.038748
# 1 -0.072456 -0.126832  0.204340  0.047925 -0.173506  0.012698
# 2  0.347483  0.340563  0.208704 -0.167646  0.078711 -0.066652
# 3 -0.140813  0.068313 -0.155587 -0.085290 -0.532761 -0.309992
# 4  0.292296 -0.007742  0.232237 -0.152113 -0.026279  0.499299
#
# [5 rows x 128 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train_scaled, y_train)
rf.score(X_test_scaled, y_test)
# Out:
# 0.975

# %%
from sklearn.metrics import classification_report
predictions = rf.predict(X_test_scaled)
print(classification_report(y_test, predictions,))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97       177
#            1       0.95      1.00      0.98       183
#
#     accuracy                           0.97       360
#    macro avg       0.98      0.97      0.97       360
# weighted avg       0.98      0.97      0.97       360

# %%
import joblib
filename = 'gen_emo_rf_model.sav'
joblib.dump(rf, filename)
# Out:
# ['gen_emo_rf_model.sav']

# %%
filename1 = 'gen_emo_rf_scaler.sav'
joblib.dump(X_scaler, filename1)
# Out:
# ['gen_emo_rf_scaler.sav']
